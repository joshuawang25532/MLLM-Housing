# %%
# Imports
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import randint, uniform

# %%
# Load Dataset
df = pd.read_csv('houses_dataset.csv')

print(f"Dataset shape: {df.shape}")
print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns)}")
print(f"\nFirst few rows:")
# df.head()
# Out:
# Dataset shape: (4853, 109)
# Rows: 4,853
# Columns: 109
#
# First few rows:

# %%
# DataFrame prep
target_col = 'financial_lastSoldPrice'
description_col = 'basic_info_description'
tax_col = 'financial_taxAssessedValue'
tax_exists = 'financial_taxAssessedValue_is_missing'

y = df[target_col].copy()
descriptions = df[description_col].copy()

columns_to_exclude = [target_col, description_col]
X = df.drop(columns=columns_to_exclude)

print(f"\nFeatures shape: {X.shape}")
print(f"Target shape: {y.shape}")
# Out:
# Features shape: (4853, 107)
# Target shape: (4853,)

# %%
# Load Gemini-encoded features
gemini_feats = pd.read_csv("gemini_encoded_descriptions.csv")

# Check alignment; assume row order matches df
if len(gemini_feats) != len(X):
    raise ValueError("Gemini encoded features row count does not match X!")

# Rename columns to avoid collision
gemini_feats = gemini_feats.add_prefix("gemini_")

# Concatenate to original X
X = pd.concat([X.reset_index(drop=True), gemini_feats.reset_index(drop=True)], axis=1)

print(f"Added Gemini features. New shape: {X.shape}")

# %%
# Data Setup
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.4, 
    random_state=9999,
    shuffle=True
)
# 0.8 Train (using K Fold), 0.2 Test

y_train = np.log1p(y_train)
y_test = np.log1p(y_test)

zipcode_cols = [col for col in X_train.columns if 'zipcode_' in col]
X_train_improved = X_train.drop(columns=zipcode_cols)
X_test_improved = X_test.drop(columns=zipcode_cols)

print(f"Dropped {len(zipcode_cols)} zipcode columns")

# What's your target variable's standard deviation?
print(f"Target std: {y_train.std():.2f}")
print(f"RMSE as % of std: {0.39 / y_train.std() * 100:.1f}%")
# Out:
# Dropped 30 zipcode columns
# Target std: 0.67
# RMSE as % of std: 58.0%

# %%
def evaluate_model(model, X, y_log, set_name):
    y_pred_log = model.predict(X)
    y_pred = np.expm1(y_pred_log)
    y_actual = np.expm1(y_log)
    
    mae = mean_absolute_error(y_actual, y_pred)
    rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
    rmsle = np.sqrt(mean_squared_error(y_log, y_pred_log))
    r2 = r2_score(y_actual, y_pred)
    
    print(f"\n{set_name} Set:")
    print(f"  MAE:   ${mae:,.2f}")
    print(f"  RMSE:  ${rmse:,.2f}")
    print(f"  RMSLE: {rmsle:.6f}")
    print(f"  R²:    {r2:.4f}")
    
    return {'mae': mae, 'rmse': rmse, 'rmsle': rmsle, 'r2': r2}

# %%
# Model definition with log transform
base_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    n_estimators=500,
    random_state=42,
    n_jobs=1,
)

from sklearn.model_selection import KFold
import numpy as np

kf = KFold(n_splits=5, shuffle=True, random_state=42)
rmse_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
    
    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        n_estimators=1000,
        early_stopping_rounds=50,
        random_state=42,
        n_jobs=-1
    )
    
    model.fit(
        X_fold_train, y_fold_train,
        eval_set=[(X_fold_val, y_fold_val)],
        verbose=False
    )
    
    preds = model.predict(X_fold_val)
    rmse = np.sqrt(np.mean((y_fold_val - preds)**2))
    rmse_scores.append(rmse)
    print(f"Fold {fold+1} RMSE: {rmse:.2f}")

print(f"\nCV RMSE: {np.mean(rmse_scores):.2f} (+/- {np.std(rmse_scores):.2f})")
# Out:
# Fold 1 RMSE: 0.36
# Fold 2 RMSE: 0.36
# Fold 3 RMSE: 0.48
# Fold 4 RMSE: 0.36
# Fold 5 RMSE: 0.28
#
# CV RMSE: 0.37 (+/- 0.06)

# %%
# Parameters tuned for one-hot encoded features
param_distributions = {
    'max_depth': randint(2, 4),  # Even shallower
    'learning_rate': uniform(0.005, 0.05),  # Lower learning rate
    'n_estimators': randint(500, 2000),  # More trees to compensate
    'min_child_weight': randint(10, 30),  # Much higher
    'subsample': uniform(0.4, 0.4),  # 0.4 to 0.8
    'colsample_bytree': uniform(0.2, 0.4),  # 0.2 to 0.6 - very aggressive
    'colsample_bynode': uniform(0.2, 0.4),  # 0.2 to 0.6
    'reg_alpha': uniform(1, 10),  # Higher L1
    'reg_lambda': uniform(5, 20),  # Much higher L2
    'gamma': uniform(1, 10),  # Higher minimum split loss
}

xgb_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1
)

random_search = RandomizedSearchCV(
    xgb_model,
    param_distributions=param_distributions,
    n_iter=100,  # More iterations since we're fighting overfitting
    cv=5,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=-1,
    verbose=0  # Set verbose to False (0)
)

random_search.fit(X_train, y_train)

print(f"Best CV RMSE: {-random_search.best_score_:.2f}")
print(f"Best params: {random_search.best_params_}")

# Check overfitting
best_model = random_search.best_estimator_
train_pred = best_model.predict(X_train)
train_rmse = np.sqrt(np.mean((y_train - train_pred)**2))
print(f"Train RMSE: {train_rmse:.2f}")
print(f"Gap (overfitting indicator): {train_rmse - (-random_search.best_score_):.2f}")
# Out:
# Best CV RMSE: 0.37
# Best params: {'colsample_bynode': 0.5272059063689973, 'colsample_bytree': 0.5442922333025374, 'gamma': 1.069521305311907, 'learning_rate': 0.03053736512887829, 'max_depth': 2, 'min_child_weight': 14, 'n_estimators': 1748, 'reg_alpha': 2.1986536733368283, 'reg_lambda': 11.752303428072558, 'subsample': 0.7771638815650077}
# Train RMSE: 0.36
# Gap (overfitting indicator): -0.01

# %%
# 1. Get the best hyperparameters from your search
best_params = random_search.best_params_
print(f"Best params: {best_params}")

# 2. Retrain on ALL your training data (train + validation combined)
# This gives the model maximum data to learn from
final_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    **best_params  # Use the best hyperparameters
)

# Fit on all training data
final_model.fit(X_train, y_train)

# 3. Evaluate on test set (only do this ONCE!)
test_pred = final_model.predict(X_test)
test_rmse = np.sqrt(np.mean((y_test - test_pred)**2))
test_mae = np.mean(np.abs(y_test - test_pred))

print(f"\n{'='*50}")
print(f"FINAL RESULTS:")
print(f"{'='*50}")
print(f"CV RMSE (5-fold):     {-random_search.best_score_:.4f}")
print(f"Test RMSE:            {test_rmse:.4f}")
print(f"Test MAE:             {test_mae:.4f}")
print(f"Difference (RMSE gap):           {abs(test_rmse - (-random_search.best_score_)):.4f}")
print(f"{'='*50}")
# Out:
# Best params: {'colsample_bynode': 0.5272059063689973, 'colsample_bytree': 0.5442922333025374, 'gamma': 1.069521305311907, 'learning_rate': 0.03053736512887829, 'max_depth': 2, 'min_child_weight': 14, 'n_estimators': 1748, 'reg_alpha': 2.1986536733368283, 'reg_lambda': 11.752303428072558, 'subsample': 0.7771638815650077}
#
# ...
# FINAL RESULTS:
# ...
# CV RMSE (5-fold):     0.3658
# Test RMSE:            0.3879
# Test MAE:             0.2082
# Difference (RMSE gap):           0.0221
# ...
